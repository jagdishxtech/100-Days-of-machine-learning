# %%
import pandas as pd
import numpy as np
from io import StringIO

# %%
df=pd.read_csv("aug_train.csv")

# %% [markdown]
# # 2.read file from url

# %%
import requests
from io import StringIO
url="https://raw.githubusercontent.com/aishwaryamate/Datasets/refs/heads/main/AirPassengers.csv"
req=requests.get(url)
data=StringIO(req.text)
data.readlines()
# Out:
# ['Month,Passengers\n',
#  '1949-01,112\n',
#  '1949-02,118\n',
#  '1949-03,132\n',
#  '1949-04,129\n',
#  '1949-05,121\n',
#  '1949-06,135\n',
#  '1949-07,148\n',
#  '1949-08,148\n',
#  '1949-09,136\n',
#  '1949-10,119\n',
#  '1949-11,104\n',
#  '1949-12,118\n',
#  '1950-01,115\n',
#  '1950-02,126\n',
#  '1950-03,141\n',
#  '1950-04,135\n',
#  '1950-05,125\n',
#  '1950-06,149\n',
#  '1950-07,170\n',
#  '1950-08,170\n',
#  '1950-09,158\n',
#  '1950-10,133\n',
#  '1950-11,114\n',
#  '1950-12,140\n',
#  '1951-01,145\n',
#  '1951-02,150\n',
#  '1951-03,178\n',
#  '1951-04,163\n',
#  '1951-05,172\n',
#  '1951-06,178\n',
#  '1951-07,199\n',
#  '1951-08,199\n',
#  '1951-09,184\n',
#  '1951-10,162\n',
#  '1951-11,146\n',
#  '1951-12,166\n',
#  '1952-01,171\n',
#  '1952-02,180\n',
#  '1952-03,193\n',
#  '1952-04,181\n',
#  '1952-05,183\n',
#  '1952-06,218\n',
#  '1952-07,230\n',
#  '1952-08,242\n',
#  '1952-09,209\n',
#  '1952-10,191\n',
#  '1952-11,172\n',
#  '1952-12,194\n',
# ...

# %% [markdown]
# ## 3. if file is tsv("tab seprated value") then we can use sep parameter in read_csv function

# %%
df=pd.read_csv("titanic.tsv",sep="\t")
df
# Out:
#        1  0  3                            Braund, Mr. Owen Harris    male  22  \
# 0      2  1  1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38
# 1      3  1  3                             Heikkinen, Miss. Laina  female  26
# 2      4  1  1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35
# 3      5  0  3                           Allen, Mr. William Henry    male  35
# 4      6  0  3                                   Moran, Mr. James    male  \N
# ..   ... .. ..                                                ...     ...  ..
# 885  887  0  2                              Montvila, Rev. Juozas    male  27
# 886  888  1  1                       Graham, Miss. Margaret Edith  female  19
# 887  889  0  3           Johnston, Miss. Catherine Helen "Carrie"  female  \N
# 888  890  1  1                              Behr, Mr. Karl Howell    male  26
# 889  891  0  3                                Dooley, Mr. Patrick    male  32
#
# ...

# %% [markdown]
# ###### As you see that first row atomatic convert into column .To handle this problem we require parameter nmaes to give a columns

# %%
df=pd.read_csv("titanic.tsv",sep="\t",names=['a','b','c','d','e','f','g','h','i','k','l','m'])
df
# Out:
#        a  b  c                                                  d       e   f  \
# 0      1  0  3                            Braund, Mr. Owen Harris    male  22
# 1      2  1  1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38
# 2      3  1  3                             Heikkinen, Miss. Laina  female  26
# 3      4  1  1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35
# 4      5  0  3                           Allen, Mr. William Henry    male  35
# ..   ... .. ..                                                ...     ...  ..
# 886  887  0  2                              Montvila, Rev. Juozas    male  27
# 887  888  1  1                       Graham, Miss. Margaret Edith  female  19
# 888  889  0  3           Johnston, Miss. Catherine Helen "Carrie"  female  \N
# 889  890  1  1                              Behr, Mr. Karl Howell    male  26
# 890  891  0  3                                Dooley, Mr. Patrick    male  32
#
# ...
