# %%
import pandas as pd
import numpy as np
import requests

# %%
import requests
import pandas as pd

data = requests.get("https://api.tvmaze.com/search/shows?q=office")

shows = []

for i in data.json():
    shows.append(i["show"])

df = pd.DataFrame(shows)

shows
# Out:
# [{'id': 526,
#   'url': 'https://www.tvmaze.com/shows/526/the-office',
#   'name': 'The Office',
#   'type': 'Scripted',
#   'language': 'English',
#   'genres': ['Comedy'],
#   'status': 'Ended',
#   'runtime': 30,
#   'averageRuntime': 30,
#   'premiered': '2005-03-24',
#   'ended': '2013-05-16',
#   'officialSite': 'http://www.nbc.com/the-office',
#   'schedule': {'time': '21:00', 'days': ['Thursday']},
#   'rating': {'average': 8.5},
#   'weight': 99,
#   'network': {'id': 1,
#    'name': 'NBC',
#    'country': {'name': 'United States',
#     'code': 'US',
#     'timezone': 'America/New_York'},
#    'officialSite': 'https://www.nbc.com/'},
#   'webChannel': None,
#   'dvdCountry': None,
#   'externals': {'tvrage': 6061, 'thetvdb': 73244, 'imdb': 'tt0386676'},
#   'image': {'medium': 'https://static.tvmaze.com/uploads/images/medium_portrait/481/1204342.jpg',
#    'original': 'https://static.tvmaze.com/uploads/images/original_untouched/481/1204342.jpg'},
# ...

# %%
df
# Out:
#       id                                                url  \
# 0    526        https://www.tvmaze.com/shows/526/the-office
# 1   1292       https://www.tvmaze.com/shows/1292/the-office
# 2  69044      https://www.tvmaze.com/shows/69044/the-office
# 3  25637  https://www.tvmaze.com/shows/25637/radiant-office
# 4  57168      https://www.tvmaze.com/shows/57168/the-office
# 5  44432    https://www.tvmaze.com/shows/44432/office-watch
# 6  28775      https://www.tvmaze.com/shows/28775/box-office
# 7  57704      https://www.tvmaze.com/shows/57704/the-office
# 8  80108  https://www.tvmaze.com/shows/80108/the-office-...
# 9  59025    https://www.tvmaze.com/shows/59025/death-office
#
#                 name      type  language                    genres   status  \
# 0         The Office  Scripted   English                  [Comedy]    Ended
# 1         The Office  Scripted   English                  [Comedy]    Ended
# ...

# %%
import requests

url = "https://instagram120.p.rapidapi.com/api/instagram/posts"

payload = {
	"username": "keke",
	"maxId": ""
}
headers = {
	"x-rapidapi-key": "1a7cf2c932msh1dbfc935a514002p1de9d3jsn690ee130534f",
	"x-rapidapi-host": "instagram120.p.rapidapi.com",
	"Content-Type": "application/json"
}

response = requests.post(url, json=payload, headers=headers)
# Out:
# {'result': {'edges': [{'node': {'code': 'DYXyzGJSuyR', 'pk': '3897807416129678481', 'id': '3897807416129678481_1141197', 'ad_id': None, 'boosted_status': None, 'boost_unavailable_identifier': None, 'boost_unavailable_reason': None, 'caption': {'has_translation': None, 'created_at': 1778874955, 'pk': '18076744958214803', 'text': 'You’ve seen me on the big screen, heard my perspectives on the podcast, and now, I’m excited to invite you into a different side of my world 👀🌴\n\nPractice by Palmer is rooted in wellness, movement, reflection, and community. The workouts are part of the practice, of course, but what we’re building inside this space goes far beyond that.\n\nWe have a special drop coming soon that I cannot wait to share with you. It’s personal, inspiring, and a reminder that no matter where you are in life, there is always room to stay curious, become a student again, and discover new parts of yourself along the way.\n\nBecome a member today to get first access to what’s comin
# ...

# %%
df=pd.DataFrame(response.json())
df
# Out:
#                                                       result
# edges      [{'node': {'code': 'DYXyzGJSuyR', 'pk': '38978...
# page_info  {'end_cursor': '3919788570455042113_1141197', ...
# version                                                   v1

# %%
import requests

url = "https://imdb236.p.rapidapi.com/api/imdb/cast/nm0000190/titles"

headers = {
	"x-rapidapi-key": "1a7cf2c932msh1dbfc935a514002p1de9d3jsn690ee130534f",
	"x-rapidapi-host": "imdb236.p.rapidapi.com",
	"Content-Type": "application/json"
}

response = requests.get(url, headers=headers)

datas=[]
for data in response.json():    
    datas.append(data)
df=pd.DataFrame(datas)

# %%
df.head(2)
# Out:
#            id                                     url  \
# 0  tt41059410  https://www.imdb.com/title/tt41059410/
# 1  tt21103218  https://www.imdb.com/title/tt21103218/
#
#                   primaryTitle                originalTitle      type  \
# 0  Bear Grylls Is Running Wild  Bear Grylls Is Running Wild  tvSeries
# 1                 The Lost Bus                 The Lost Bus     movie
#
#                                          description  \
# 0  Bear Grylls guides celebrities through extreme...
# 1  A wayward school bus driver and a dedicated sc...
#
#                                         primaryImage  \
# 0  https://m.media-amazon.com/images/M/MV5BMThjOT...
# 1  https://m.media-amazon.com/images/M/MV5BZTIzNm...
#
#                                           thumbnails trailer contentRating  \
# 0  [{'url': 'https://m.media-amazon.com/images/M/...    None          None
# 1  [{'url': 'https://m.media-amazon.com/images/M/...    None             R
#
# ...

# %%
df.to_csv("movie.csv")
